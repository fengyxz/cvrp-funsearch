# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 设置seaborn风格，采用适合学术论文的风格
sns.set_style("white")
sns.set_context("paper")

# 构造数据，确保所有列表长度一致（这里以7个实例为例）
data = {
    'Data': [
        'A-n32-k5', 'A-n37-k5', 'A-n45-k6', 'A-n48-k7', 
        'A-n53-k7', 'A-n63-k10', 'A-n80-k10'  # 7个实例
    ],
    '2-opt': [
        1168, 892, 1265, 1439, 1381, 1864, 2155  # 7个值
    ],
    'LNS': [
        849, 666, 937, 1101, 1016, 1400, 1834  # 7个值
    ],
    'TabuS': [
        953, 766, 1126, 1225, 1185, 1668, 1913  # 7个值
    ],
    'SA': [
        960, 762, 1047, 1229, 1191, 1564, 1931  # 7个值
    ],
    'Ortools': [
        782, 656, 1034, 1051, 1028, 1335, 1831  # 7个值
    ]
}

df = pd.DataFrame(data)
df.set_index('Data', inplace=True)

# 绘制折线图
ax = df.plot(kind='line', marker='o', figsize=(8, 6), linewidth=1.5, alpha=0.7)

# 设置标题和坐标轴标签
ax.set_title('Comparison of Solving Quality for Different CVRP Methods (Set A)', fontsize=16, fontweight='bold')
ax.set_xlabel('Instances', fontsize=14)
ax.set_ylabel('Solution Quality', fontsize=14)

# 旋转x轴标签（确保标签数与刻度数一致）
ax.set_xticks(range(len(df.index)))  # 设置7个刻度位置（0到6）
ax.set_xticklabels(df.index, rotation=0, ha='right', fontsize=12)  # 7个标签，与位置数匹配

# 设置图例
ax.legend(title='Methods', fontsize=12, loc='upper left')

# 去除顶部和右侧边框
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# 调整布局
plt.tight_layout()
# 保存图表为高质量图片（可根据需求调整格式，如pdf适合论文排版）
plt.savefig('cvrp_solving_quality_comparison_setA.png', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# 设置seaborn风格，采用适合学术论文的风格
sns.set_style("white")
sns.set_context("paper")

# 构造数据，确保所有列表长度一致（这里以7个实例为例）
data = {'Data': ['X-n110-k13', 'X-n115-k10', 'X-n120-k6', 'X-n139-k10'], 
        '2-opt': [19320, 17562, 15188, 17218],
        'LNS': [15867, 13958, 14294, 14905], 
        'TabuS': [16845, 15792, 15794, 15931], 
        'SA': [16565, 14870, 15398, 15409], 
        'Ortools': [15550, 13379, 13995, 14633]}
df = pd.DataFrame(data)
df.set_index('Data', inplace=True)

# 绘制折线图
ax = df.plot(kind='line', marker='o', figsize=(8, 6), linewidth=1.5, alpha=0.7)

# 设置标题和坐标轴标签
ax.set_title('Comparison of Solving Quality for Different CVRP Methods (Set X)', fontsize=16, fontweight='bold')
ax.set_xlabel('Instances', fontsize=14)
ax.set_ylabel('Solution Quality', fontsize=14)

# 旋转x轴标签（确保标签数与刻度数一致）
ax.set_xticks(range(len(df.index)))  # 设置7个刻度位置（0到6）
ax.set_xticklabels(df.index, rotation=0, ha='right', fontsize=12)  # 7个标签，与位置数匹配

# 设置图例
ax.legend(title='Methods', fontsize=12, loc='upper left')

# 去除顶部和右侧边框
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# 调整布局
plt.tight_layout()
# 保存图表为高质量图片（可根据需求调整格式，如pdf适合论文排版）
plt.savefig('cvrp_solving_quality_comparison_setX.png', dpi=300)
plt.show()

# %%
# Out:
# {'Data': ['X-n110-k13', 'X-n115-k10', 'X-n120-k6', 'X-n139-k10'], '2-opt': [19320, 17562, 15188, 17218], 'LNS': [15867, 13958, 14294, 14905], 'TabuS': [16845, 15792, 15794, 15931], 'SA': [16565, 14870, 15398, 15409], 'Ortools': [15550, 13379, 13995, 14633]}
