# %%
import os
import re
import vrplib
import random
import matplotlib.pyplot as plt
import numpy as np
from collections import deque
import random

# %%
#按文件名排序加载数据
def read_all_instances(root_folder, ending='.tsp'):  
    instances = []  
    
    def extract_k_number(file_name):  
        match = re.search(r'k(\d+)', file_name)  
        if match:  
            return int(match.group(1))
        return float('inf')  

    file_names = sorted(  
        [file_name for file_name in os.listdir(root_folder) if file_name.endswith(ending)],  
        key=extract_k_number 
    )   
    for file_name in file_names:  
        instance = vrplib.read_instance(str(os.path.join(root_folder, file_name))) 
        if instance:  
            instances.append(instance)  
            print(f'Successfully read {file_name}')  
        else:
            print(f'Failed to read {file_name}')  
    
    return instances

# %%
root_folder = './data/cvrp/new_data/'  
cvrp_instances = read_all_instances(root_folder, ending='.vrp')
# Out:
# Successfully read A-n34-k5.vrp
# Successfully read A-n32-k5.vrp
# Successfully read A-n36-k5.vrp
# Successfully read A-n33-k5.vrp
# Successfully read A-n37-k5.vrp
# Successfully read A-n38-k5.vrp
# Successfully read A-n39-k5.vrp
# Successfully read A-n39-k6.vrp
# Successfully read A-n37-k6.vrp
# Successfully read A-n33-k6.vrp
# Successfully read A-n44-k6.vrp
# Successfully read A-n45-k6.vrp
# Successfully read A-n53-k7.vrp
# Successfully read A-n46-k7.vrp
# Successfully read A-n54-k7.vrp
# Successfully read A-n45-k7.vrp
# Successfully read A-n48-k7.vrp
# Successfully read A-n62-k8.vrp
# Successfully read A-n65-k9.vrp
# Successfully read A-n69-k9.vrp
# Successfully read A-n61-k9.vrp
# Successfully read A-n64-k9.vrp
# Successfully read A-n55-k9.vrp
# Successfully read A-n60-k9.vrp
# Successfully read A-n63-k9.vrp
# Successfully read A-n63-k10.vrp
# Successfully read A-n80-k10.vrp

# %%
# Function to visualize solution
def plot_CVRP_solution(routes, node_coords):
    plt.figure(figsize=(10, 8))
    
    # Plot nodes
    for i, (x, y) in enumerate(node_coords):
        plt.scatter(x, y, c='blue' if i == 0 else 'red')
        plt.text(x, y, f'{i}', fontsize=9, ha='right')
    
    # Plot routes
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    for vehicle, route in enumerate(routes):
        route_coords = [node_coords[0]] + [node_coords[node] for node in route] + [node_coords[0]]
        x_coords, y_coords = zip(*route_coords)
        plt.plot(x_coords, y_coords, c=colors[vehicle % len(colors)], label=f'Vehicle {vehicle + 1}')
    
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.title('Vehicle Routing Problem Solution')
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to test vehicle capacity constraint
def test_capacity_constraint(routes, demands, vehicle_capacity):
    for vehicle, route in enumerate(routes):
        total_demand = sum(demands[node] for node in route)
        if total_demand > vehicle_capacity:
            print(f"Vehicle {vehicle + 1} exceeds capacity: {total_demand} > {vehicle_capacity}")
        else:
            print(f"Vehicle {vehicle + 1} is within capacity: {total_demand} <= {vehicle_capacity}")


# Function to calculate route distance
def calculate_route_distance(route, distance_matrix):
    distance = 0
    if route:
        distance += distance_matrix[0][route[0]]  # From depot to first node
        for i in range(1, len(route)):
            distance += distance_matrix[route[i-1]][route[i]]
        distance += distance_matrix[route[-1]][0]  # From last node back to depot
    return distance

# Function to calculate total distance of all routes (CVRP)
def total_distance(routes, distance_matrix):
    return sum(calculate_route_distance(route, distance_matrix) for route in routes)


# Generate initial solution using a greedy approach
def greedy_initial_solution():
    routes = [[] for _ in range(num_vehicles)]
    current_load = [0] * num_vehicles
    visited = [False] * num_nodes
    visited[0] = True  # Starting from the depot

    for vehicle in range(num_vehicles):
        current_node = 0
        while True:
            next_node = None
            min_distance = float('inf')
            for i in range(1, num_nodes):
                if not visited[i] and current_load[vehicle] + demands[i] <= vehicle_capacity:
                    if distance_matrix[current_node][i] < min_distance:
                        min_distance = distance_matrix[current_node][i]
                        next_node = i
            if next_node is None:
                break
            routes[vehicle].append(next_node)
            current_load[vehicle] += demands[next_node]
            visited[next_node] = True
            current_node = next_node
    return routes

# %%
# a function for checking feasibility
def is_feasible(route, demands, vehicle_capacity):
    total_demand = sum(demands[node] for node in route)
    return total_demand <= vehicle_capacity # True or False

# new algorithm for solving CVRPs with local search 
def generate_neighbors(routes, demands, vehicle_capacity, num_rand_swaps = 10):
    neighbors = []
    for i in range(num_vehicles):
        for j in range(i +1, num_vehicles):
            # Route 1 = [1,2,3], Route 2 = [4,5, 6] -> Swap across routes [2,5]. New route 1: [1,5,3], new route 2: [4,2,6]
            for _ in range(num_rand_swaps):
                new_routes = [route.copy() for route in routes]
                if new_routes[i] and new_routes[j]:
                    node_i = random.choice(new_routes[i])
                    node_j = random.choice(new_routes[j])
                    idx_i = new_routes[i].index(node_i)
                    idx_j = new_routes[j].index(node_j)
                    new_routes[i][idx_i], new_routes[j][idx_j] = new_routes[j][idx_j], new_routes[i][idx_i]

                    # check for feasibility
                    if is_feasible(new_routes[i], demands, vehicle_capacity) and is_feasible(new_routes[j], demands, vehicle_capacity):
                        neighbors.append(new_routes)
    return neighbors

# %%
def simulated_annealing(initial_routes, demands, vehicle_capacity, initial_temp=5000, cooling_rate=0.995, stopping_temp=1):
    current_routes = initial_routes
    best_routes = initial_routes
    current_distance = total_distance(initial_routes, distance_matrix)
    best_distance = current_distance
    temperature = initial_temp

    while temperature > stopping_temp:
        neighbors = generate_neighbors(current_routes, demands, vehicle_capacity)
        # sort neighbors by total distance
        neighbors.sort(key=lambda x: total_distance(x, distance_matrix))
        neighbor = neighbors[0]
        neighbor_distance = total_distance(neighbor, distance_matrix)

        if neighbor_distance < current_distance or random.random() < np.exp((current_distance - neighbor_distance) / temperature):
            current_routes = neighbor
            current_distance = neighbor_distance
            
            if current_distance < best_distance:
                best_routes = current_routes
                best_distance = current_distance

        temperature *= cooling_rate

    return best_routes, best_distance

# %%
initial_temp = 5000
cooling_rate = 0.998
stopping_temp = 0.1


for i in range(len(cvrp_instances)):
    cvrp_instance = cvrp_instances[i]
    vehicle_capacity = cvrp_instance['capacity']
    demands = cvrp_instance['demand']
    distance_matrix = cvrp_instance['edge_weight']
    node_coords = cvrp_instance['node_coord']  #数据中点的坐标
    print("=====================",cvrp_instance['comment'],"=====================")
    match = re.search(r"No of trucks: (\d+)", str(cvrp_instance['comment']))  
    if match:  
        num_vehicles = int(match.group(1))  
    num_nodes = len(node_coords)
    print("Number of Nodes:",num_nodes)
    initial_routes = greedy_initial_solution()
    optimized_routes_sa, optimized_distance_sa = simulated_annealing(initial_routes, demands, vehicle_capacity, initial_temp, cooling_rate, stopping_temp)
    
    print("Final Solution SA: ", optimized_routes_sa)
    print("Final Distance SA: ", optimized_distance_sa)
    
    # Plot and test the solution
    #plot_CVRP_solution(optimized_routes_sa, node_coords)
    test_capacity_constraint(optimized_routes_sa, demands, vehicle_capacity)
# Out:
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 778) =====================
# Number of Nodes: 34
# Final Solution SA:  [[4, 33, 2, 22, 3, 12, 9, 16], [29, 27, 1, 23, 11, 19, 17], [20, 18, 21, 32, 28, 31, 25, 10], [14, 15, 6, 8, 7, 13], [24, 30, 5, 26]]
# Final Distance SA:  823.9991784135154
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 88 <= 100
# Vehicle 5 is within capacity: 74 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 784) =====================
# Number of Nodes: 32
# Final Solution SA:  [[24, 14, 6, 23, 11, 4, 22, 18, 8, 20], [12, 1, 16, 5, 25, 10, 29], [7, 21, 31, 19, 17, 13, 26], [3, 2, 28, 9, 15, 27], [30]]
# Final Distance SA:  982.4898101521643
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 98 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 14 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 799) =====================
# Number of Nodes: 36
# Final Solution SA:  [[20, 5, 25, 27, 24, 11, 16], [1, 22, 18, 32, 30, 29, 17, 21], [9, 28, 12, 3, 6, 19, 31, 33, 13], [15, 8, 35, 2, 34, 14, 4, 23], [7, 26, 10]]
# Final Distance SA:  916.5980380106098
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 91 <= 100
# Vehicle 3 is within capacity: 98 <= 100
# Vehicle 4 is within capacity: 95 <= 100
# Vehicle 5 is within capacity: 58 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 661) =====================
# Number of Nodes: 33
# Final Solution SA:  [[28, 18, 29, 16, 12, 5, 27, 4], [30, 25, 26, 8, 7, 13, 32, 20], [11, 3, 9, 17, 10, 15], [24, 6, 31, 1, 21, 14, 19], [2, 22, 23]]
# Final Distance SA:  778.303020159776
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 93 <= 100
# Vehicle 5 is within capacity: 56 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 669) =====================
# Number of Nodes: 37
# Final Solution SA:  [[15, 16, 22, 7, 4, 33, 5, 6, 10], [25, 18, 35, 31, 28, 26, 30, 32, 29, 34], [13, 12, 17, 14, 20, 2, 19, 3], [36, 24, 9, 8, 27, 11, 23, 1], [21]]
# Final Distance SA:  797.5774368524714
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 86 <= 100
# Vehicle 5 is within capacity: 23 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 730) =====================
# Number of Nodes: 38
# Final Solution SA:  [[21, 16, 4, 1, 3, 12, 26, 23, 35, 33], [2, 9, 8, 36, 17, 13, 15, 24], [10, 30, 34, 6, 25, 29], [18, 19, 28, 31, 37, 5, 14], [32, 20, 7, 11, 27, 22]]
# Final Distance SA:  817.9199527328155
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 84 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 822) =====================
# Number of Nodes: 39
# Final Solution SA:  [[14, 4, 12, 33, 25, 19], [31, 1, 23, 20, 29, 16, 7, 3, 22, 37, 34, 26], [21, 30, 13, 28, 6, 36, 27, 8], [18, 2, 35, 24, 17, 11], [15, 5, 32, 10, 38, 9]]
# Final Distance SA:  884.0778597806528
# Vehicle 1 is within capacity: 87 <= 100
# Vehicle 2 is within capacity: 98 <= 100
# Vehicle 3 is within capacity: 96 <= 100
# Vehicle 4 is within capacity: 98 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 831) =====================
# Number of Nodes: 39
# Final Solution SA:  [[24, 29, 9, 28], [3, 12, 38, 37, 31, 35, 25, 14, 30], [20, 32, 16, 10, 27, 18, 1], [26, 5, 11, 36, 17, 23, 21, 34, 22, 6], [7, 4, 19, 33, 2, 8], [13, 15]]
# Final Distance SA:  913.7041573510722
# Vehicle 1 is within capacity: 55 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 84 <= 100
# Vehicle 6 is within capacity: 88 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 949) =====================
# Number of Nodes: 37
# Final Solution SA:  [[36, 29, 7, 14, 18, 4, 19, 5, 1, 20], [16, 21, 2, 28, 9, 33, 23, 12], [10, 11, 22, 26, 34, 17], [13, 30, 15, 32, 27], [35, 25, 24], [8, 3, 31, 6]]
# Final Distance SA:  1184.9475459804266
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 88 <= 100
# Vehicle 6 is within capacity: 82 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 742) =====================
# Number of Nodes: 33
# Final Solution SA:  [[11, 29, 19, 6, 23, 24, 31], [25, 21, 16, 30, 27, 28], [18, 7, 2, 20, 9, 15, 3], [13, 8, 4, 26, 22, 5], [32, 10, 12], [14, 17, 1]]
# Final Distance SA:  841.6183954762017
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 93 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 89 <= 100
# Vehicle 6 is within capacity: 59 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 937) =====================
# Number of Nodes: 44
# Final Solution SA:  [[15, 28, 27, 19, 24, 8, 31], [17, 39, 12, 3, 6, 22, 36, 9, 38, 41], [14, 13, 43, 40, 29, 2], [33, 10, 37, 42, 32, 21, 5, 7], [34, 26, 11, 30, 23, 25], [35, 1, 18, 20, 16, 4]]
# Final Distance SA:  1042.5315363279299
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 95 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 94 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 86 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 944) =====================
# Number of Nodes: 45
# Final Solution SA:  [[32, 13, 20, 5, 8, 21, 41, 33], [23, 7, 29, 27, 34, 11, 19, 40, 26], [38, 2, 25, 12, 39, 42, 22, 28], [31, 35, 14, 44, 6, 1], [24, 37, 17, 18, 43], [9, 15, 36, 16, 4, 10, 3]]
# Final Distance SA:  1072.1245876882133
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 98 <= 100
# Vehicle 3 is within capacity: 88 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1010) =====================
# Number of Nodes: 53
# Final Solution SA:  [[51, 40, 18, 29, 49, 44, 10, 26, 37, 2, 1], [31, 27, 35, 38, 30, 22, 28, 4], [14, 13, 52, 34, 21, 39], [47, 45, 42, 7, 9, 41, 17], [25, 12, 16, 48, 50, 36, 43, 23, 19, 15, 32], [11, 24, 5, 3, 20, 6], [8, 46, 33]]
# Final Distance SA:  1307.4498938171755
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 97 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 94 <= 100
# Vehicle 7 is within capacity: 81 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 914) =====================
# Number of Nodes: 46
# Final Solution SA:  [[28, 21, 41, 20, 34, 40, 1, 42, 33, 8, 11], [36, 5, 32, 14, 13, 26, 43, 45, 6, 38], [9, 39, 7, 25, 44, 18], [4, 30, 2, 37, 10], [22, 3, 12, 35, 24, 16], [29, 31, 27, 15, 19, 17], [23]]
# Final Distance SA:  1098.5185323821506
# Vehicle 1 is within capacity: 96 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 97 <= 100
# Vehicle 7 is within capacity: 18 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1167) =====================
# Number of Nodes: 54
# Final Solution SA:  [[43, 4, 28, 5, 7, 39, 50, 23, 20], [52, 30, 16, 6, 32, 13, 33, 38, 26, 35], [18, 49, 29, 15, 10, 17, 45, 1, 36], [34, 41, 46, 51, 42, 24, 2, 12, 27, 14], [25, 47, 37, 48, 40, 31, 11], [3, 22, 19, 8], [53, 44, 9, 21]]
# Final Distance SA:  1374.136230748766
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 74 <= 100
# Vehicle 7 is within capacity: 100 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1146) =====================
# Number of Nodes: 45
# Final Solution SA:  [[35, 39, 26, 34, 28, 6, 2, 21, 9, 8], [12, 32, 13, 18, 7, 16, 20, 40], [38, 17, 23, 25, 15, 10, 14], [5, 30, 19, 36, 31], [3, 11, 43, 41, 29, 27], [4, 33, 44, 24], [42, 1, 37, 22]]
# Final Distance SA:  1326.6270221115897
# Vehicle 1 is within capacity: 97 <= 100
# Vehicle 2 is within capacity: 95 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 83 <= 100
# Vehicle 5 is within capacity: 99 <= 100
# Vehicle 6 is within capacity: 94 <= 100
# Vehicle 7 is within capacity: 66 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1073) =====================
# Number of Nodes: 48
# Final Solution SA:  [[17, 14, 32, 22, 1, 5, 43, 31, 44], [41, 2, 33, 10, 21, 29, 47], [40, 36, 3, 37, 7, 28, 16], [23, 12, 6, 19, 25, 38], [34, 15, 26, 20, 8, 39, 27], [24, 42, 11, 4, 13, 46, 30, 9, 45], [18, 35]]
# Final Distance SA:  1272.8052523949884
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 36 <= 100
# ===================== (Augerat et al, No of trucks: 8, Optimal value: 1288) =====================
# Number of Nodes: 62
# Final Solution SA:  [[28, 10, 29, 61, 32, 43, 8, 51, 7, 20], [53, 12, 13, 30, 18, 5, 60, 34, 31, 25, 11, 4, 21, 41, 54, 19], [52, 36, 16, 37, 22, 44, 2, 38], [3, 39, 27, 23, 9, 1, 14], [6, 57, 50, 17, 33, 58], [40, 55, 59, 26, 35, 49], [46, 42, 24, 47, 45], [15, 48, 56]]
# Final Distance SA:  1463.6209309238643
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 86 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 93 <= 100
# Vehicle 5 is within capacity: 89 <= 100
# Vehicle 6 is within capacity: 97 <= 100
# Vehicle 7 is within capacity: 99 <= 100
# Vehicle 8 is within capacity: 69 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1174) =====================
# Number of Nodes: 65
# Final Solution SA:  [[46, 31, 47, 64, 6, 26, 57, 48, 45, 5], [51, 62, 28, 63, 11, 54, 7, 39], [49, 43, 15, 27, 14, 22, 4, 42, 61, 32], [34, 9, 36, 3, 35, 37], [33, 55, 29, 18, 21, 25, 13, 12], [23, 1, 19, 24, 52, 40, 53], [41, 38, 2, 16, 50, 30], [8, 10, 56, 59, 44], [17, 60, 20, 58]]
# Final Distance SA:  1636.6813181365835
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 90 <= 100
# Vehicle 8 is within capacity: 98 <= 100
# Vehicle 9 is within capacity: 91 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1159) =====================
# Number of Nodes: 69
# Final Solution SA:  [[68, 41, 20, 59, 36, 48, 1, 62], [34, 57, 54, 11, 46, 5, 32, 17, 10, 16, 26], [7, 2, 21, 55, 60, 4, 47, 25, 14, 27], [31, 18, 53, 9, 30, 6, 51, 3, 15, 44], [24, 8, 38, 56, 39, 40], [65, 64, 61, 67, 33, 49, 66, 58, 19], [22, 12, 29, 52, 43], [28, 42, 63, 37, 50], [13, 35, 45, 23]]
# Final Distance SA:  1431.6254319842644
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# Vehicle 7 is within capacity: 86 <= 100
# Vehicle 8 is within capacity: 82 <= 100
# Vehicle 9 is within capacity: 80 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1034) =====================
# Number of Nodes: 61
# Final Solution SA:  [[14, 23, 26, 43, 55], [35, 18, 48, 13, 50, 12, 22, 4, 32, 33], [24, 10, 59, 45, 37, 30, 42], [17, 57, 52, 31, 60, 11, 28, 39], [44, 1, 16, 34, 47, 56, 27, 51], [15, 3, 38], [58, 25, 20, 29, 36, 21, 9], [19, 6, 41, 2, 5, 54, 46], [7, 8, 53, 49, 40]]
# Final Distance SA:  1213.5416489511206
# Vehicle 1 is within capacity: 97 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 96 <= 100
# Vehicle 4 is within capacity: 97 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 100 <= 100
# Vehicle 8 is within capacity: 99 <= 100
# Vehicle 9 is within capacity: 96 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1401) =====================
# Number of Nodes: 64
# Final Solution SA:  [[6, 10, 41, 56, 52, 13, 61, 60, 16, 32], [29, 15, 30, 27, 26, 35, 28, 38], [45, 3, 53, 19, 9, 20, 42], [25, 18, 22, 12, 43, 1, 17], [37, 59, 31, 50, 49, 55], [51, 23, 34, 4, 54, 46, 8], [11, 57, 14, 21, 7, 40, 36, 39, 44], [24, 47, 63, 2, 58, 5], [62, 48, 33]]
# Final Distance SA:  1574.6739916824922
# Vehicle 1 is within capacity: 91 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 72 <= 100
# Vehicle 6 is within capacity: 97 <= 100
# Vehicle 7 is within capacity: 91 <= 100
# Vehicle 8 is within capacity: 100 <= 100
# Vehicle 9 is within capacity: 99 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1073) =====================
# Number of Nodes: 55
# Final Solution SA:  [[8, 32, 10, 5, 38, 47, 40, 53], [41, 24, 52, 6, 1, 44, 23], [4, 7, 31, 20, 26, 48, 50, 29], [37, 3, 33, 34, 46, 42], [30, 22, 27, 13, 28, 54, 19], [36, 16, 39, 49, 9, 35, 43], [2, 51, 11, 15, 17, 14], [18, 45], [25, 21, 12]]
# Final Distance SA:  1315.5690407580341
# Vehicle 1 is within capacity: 95 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 98 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 98 <= 100
# Vehicle 8 is within capacity: 87 <= 100
# Vehicle 9 is within capacity: 61 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1354) =====================
# Number of Nodes: 60
# Final Solution SA:  [[58, 39, 50, 55, 15, 8, 57, 37, 33], [16, 20, 25, 46, 3, 11, 4, 21, 47, 35, 19, 18], [6, 31, 28, 44, 53, 2, 40], [34, 24, 1, 54, 22, 36, 49, 30], [32, 43, 56, 26, 17, 27, 38], [52, 13, 7, 29, 59], [23, 42, 5, 10, 48], [45, 51, 9, 12], [14, 41]]
# Final Distance SA:  1608.8024185745883
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# Vehicle 7 is within capacity: 100 <= 100
# Vehicle 8 is within capacity: 100 <= 100
# Vehicle 9 is within capacity: 34 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1616) =====================
# Number of Nodes: 63
# Final Solution SA:  [[26, 16, 53, 21, 32, 40, 14, 58, 55], [11, 19, 15, 56, 44, 33], [50, 51, 57, 62, 23, 39, 52, 13], [20, 54, 29, 30, 2, 5, 27, 49], [37, 6, 43, 4, 18, 47, 46, 1, 31, 42], [12, 28, 22, 17, 35, 10, 7], [8, 24, 59, 45, 34], [61, 48, 36, 60, 25], [3, 41, 38, 9]]
# Final Distance SA:  1860.2386540100047
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 98 <= 100
# Vehicle 4 is within capacity: 97 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# Vehicle 7 is within capacity: 97 <= 100
# Vehicle 8 is within capacity: 96 <= 100
# Vehicle 9 is within capacity: 90 <= 100
# ===================== (Augerat et al, No of trucks: 10, Optimal value: 1314) =====================
# Number of Nodes: 63
# Final Solution SA:  [[48, 36, 52, 38, 4, 50, 7], [20, 26, 13, 28, 57, 47, 11], [17, 62, 31, 24, 21, 61, 54, 40, 29], [30, 43, 10, 59, 5, 18, 49, 15, 45], [25, 56, 53, 14, 1, 41, 42, 19, 39], [32, 44, 34, 51, 58, 22, 23], [27, 6, 35, 8, 16], [46, 60], [3, 2, 9, 12], [37, 33, 55]]
# Final Distance SA:  1718.4884789267226
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 98 <= 100
# Vehicle 7 is within capacity: 96 <= 100
# Vehicle 8 is within capacity: 85 <= 100
# Vehicle 9 is within capacity: 84 <= 100
# Vehicle 10 is within capacity: 72 <= 100
# ===================== (Augerat et al, No of trucks: 10, Optimal value: 1763) =====================
# Number of Nodes: 80
# Final Solution SA:  [[44, 12, 5, 17, 31, 29, 74, 51, 13], [30, 8, 37, 2, 68, 16, 43, 59], [49, 73, 66, 67, 70, 38, 58, 50, 76], [53, 39, 60, 3, 77, 42], [6, 78, 61, 57, 20, 75, 27], [21, 10, 63, 52, 79, 34, 24, 23], [4, 45, 22, 32, 72, 54, 9, 33, 15, 64], [62, 11, 28, 48, 18, 14, 71], [36, 25, 41, 55, 56, 69, 65, 35, 26, 47, 19, 46], [7, 1, 40]]
# Final Distance SA:  1951.8175070674627
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 94 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 95 <= 100
# Vehicle 5 is within capacity: 93 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 99 <= 100
# Vehicle 8 is within capacity: 99 <= 100
# Vehicle 9 is within capacity: 100 <= 100
# Vehicle 10 is within capacity: 63 <= 100
