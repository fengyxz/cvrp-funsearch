# %%
import os
import re
import vrplib
import random
import matplotlib.pyplot as plt
import numpy as np
from collections import deque

# %% [markdown]
# # 准备工作

# %%
#按文件名排序加载数据
def read_all_instances(root_folder, ending='.tsp'):  
    instances = []  
    
    def extract_k_number(file_name):  
        match = re.search(r'k(\d+)', file_name)  
        if match:  
            return int(match.group(1))
        return float('inf')  

    file_names = sorted(  
        [file_name for file_name in os.listdir(root_folder) if file_name.endswith(ending)],  
        key=extract_k_number 
    )   
    for file_name in file_names:  
        instance = vrplib.read_instance(str(os.path.join(root_folder, file_name))) 
        if instance:  
            instances.append(instance)  
            print(f'Successfully read {file_name}')  
        else:
            print(f'Failed to read {file_name}')  
    
    return instances

# %%
root_folder = './data/cvrp/new_data/'  
cvrp_instances = read_all_instances(root_folder, ending='.vrp')
# Out:
# Successfully read A-n34-k5.vrp
# Successfully read A-n32-k5.vrp
# Successfully read A-n36-k5.vrp
# Successfully read A-n33-k5.vrp
# Successfully read A-n37-k5.vrp
# Successfully read A-n38-k5.vrp
# Successfully read A-n39-k5.vrp
# Successfully read A-n39-k6.vrp
# Successfully read A-n37-k6.vrp
# Successfully read A-n33-k6.vrp
# Successfully read A-n44-k6.vrp
# Successfully read A-n45-k6.vrp
# Successfully read A-n53-k7.vrp
# Successfully read A-n46-k7.vrp
# Successfully read A-n54-k7.vrp
# Successfully read A-n45-k7.vrp
# Successfully read A-n48-k7.vrp
# Successfully read A-n62-k8.vrp
# Successfully read A-n65-k9.vrp
# Successfully read A-n69-k9.vrp
# Successfully read A-n61-k9.vrp
# Successfully read A-n64-k9.vrp
# Successfully read A-n55-k9.vrp
# Successfully read A-n60-k9.vrp
# Successfully read A-n63-k9.vrp
# Successfully read A-n63-k10.vrp
# Successfully read A-n80-k10.vrp

# %%
# Function to visualize solution
def plot_CVRP_solution(routes, node_coords):
    plt.figure(figsize=(10, 8))
    
    # Plot nodes
    for i, (x, y) in enumerate(node_coords):
        plt.scatter(x, y, c='blue' if i == 0 else 'red')
        plt.text(x, y, f'{i}', fontsize=9, ha='right')
    
    # Plot routes
    colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k']
    for vehicle, route in enumerate(routes):
        route_coords = [node_coords[0]] + [node_coords[node] for node in route] + [node_coords[0]]
        x_coords, y_coords = zip(*route_coords)
        plt.plot(x_coords, y_coords, c=colors[vehicle % len(colors)], label=f'Vehicle {vehicle + 1}')
    
    plt.xlabel('X Coordinate')
    plt.ylabel('Y Coordinate')
    plt.title('Vehicle Routing Problem Solution')
    plt.legend()
    plt.grid(True)
    plt.show()

# Function to test vehicle capacity constraint
def test_capacity_constraint(routes, demands, vehicle_capacity):
    for vehicle, route in enumerate(routes):
        total_demand = sum(demands[node] for node in route)
        if total_demand > vehicle_capacity:
            print(f"Vehicle {vehicle + 1} exceeds capacity: {total_demand} > {vehicle_capacity}")
        else:
            print(f"Vehicle {vehicle + 1} is within capacity: {total_demand} <= {vehicle_capacity}")


# Function to calculate route distance
def calculate_route_distance(route, distance_matrix):
    distance = 0
    if route:
        distance += distance_matrix[0][route[0]]  # From depot to first node
        for i in range(1, len(route)):
            distance += distance_matrix[route[i-1]][route[i]]
        distance += distance_matrix[route[-1]][0]  # From last node back to depot
    return distance

# Function to calculate total distance of all routes (CVRP)
def total_distance(routes, distance_matrix):
    return sum(calculate_route_distance(route, distance_matrix) for route in routes)


# Generate initial solution using a greedy approach
def greedy_initial_solution():
    routes = [[] for _ in range(num_vehicles)]
    current_load = [0] * num_vehicles
    visited = [False] * num_nodes
    visited[0] = True  # Starting from the depot

    for vehicle in range(num_vehicles):
        current_node = 0
        while True:
            next_node = None
            min_distance = float('inf')
            for i in range(1, num_nodes):
                if not visited[i] and current_load[vehicle] + demands[i] <= vehicle_capacity:
                    if distance_matrix[current_node][i] < min_distance:
                        min_distance = distance_matrix[current_node][i]
                        next_node = i
            if next_node is None:
                break
            routes[vehicle].append(next_node)
            current_load[vehicle] += demands[next_node]
            visited[next_node] = True
            current_node = next_node
    return routes

# %% [markdown]
# # 禁忌搜索算法

# %%
# a function for checking feasibility
def is_feasible(route, demands, vehicle_capacity):
    total_demand = sum(demands[node] for node in route)
    return total_demand <= vehicle_capacity # True or False

# new algorithm for solving CVRPs with local search 
def generate_neighbors(routes, demands, vehicle_capacity, num_rand_swaps = 10):
    neighbors = []
    for i in range(num_vehicles):
        for j in range(i +1, num_vehicles):
            # Route 1 = [1,2,3], Route 2 = [4,5, 6] -> Swap across routes [2,5]. New route 1: [1,5,3], new route 2: [4,2,6]
            for _ in range(num_rand_swaps):
                new_routes = [route.copy() for route in routes]
                if new_routes[i] and new_routes[j]:
                    node_i = random.choice(new_routes[i])
                    node_j = random.choice(new_routes[j])
                    idx_i = new_routes[i].index(node_i)
                    idx_j = new_routes[j].index(node_j)
                    new_routes[i][idx_i], new_routes[j][idx_j] = new_routes[j][idx_j], new_routes[i][idx_i]

                    # check for feasibility
                    if is_feasible(new_routes[i], demands, vehicle_capacity) and is_feasible(new_routes[j], demands, vehicle_capacity):
                        neighbors.append(new_routes)
    return neighbors

# %%
# tabu search

def tabu_search_cvrp(initial_routes, demands, vehicle_capacity, max_iterations = 2000, tabu_size = 20, num_random_swaps = 10):
    best_routes = initial_routes
    best_distance = total_distance(initial_routes, distance_matrix)
    current_routes = initial_routes

    tabu_list = deque(maxlen= tabu_size) # FIFO logic

    for _ in range(max_iterations):
        neighbors = generate_neighbors(current_routes, demands, vehicle_capacity, num_random_swaps)
        best_neighbor = None
        best_neighbor_distance = float('inf')

        for neighbor in neighbors:
            neighbor_distance = total_distance(neighbor, distance_matrix)
            if neighbor_distance < best_neighbor_distance and neighbor not in tabu_list:
                best_neighbor = neighbor
                best_neighbor_distance = neighbor_distance

        
        if best_neighbor and best_neighbor_distance < best_distance:
            best_routes = best_neighbor
            best_distance = best_neighbor_distance
            tabu_list.append(best_neighbor)
        
        current_routes = best_neighbor if best_neighbor else current_routes
    
    return best_routes, best_distance

# %%
max_iterations = 2000  # 最大迭代次数  
tabu_size = 10         # 禁忌列表大小  
num_random_swaps = 10  # 每轮随机交换的次数

for i in range(len(cvrp_instances)):
    cvrp_instance = cvrp_instances[i]
    vehicle_capacity = cvrp_instance['capacity']
    demands = cvrp_instance['demand']
    distance_matrix = cvrp_instance['edge_weight']
    node_coords = cvrp_instance['node_coord']
    print("=====================",cvrp_instance['comment'],"=====================")
    match = re.search(r"No of trucks: (\d+)", str(cvrp_instance['comment']))  
    if match:  
        num_vehicles = int(match.group(1))  
    num_nodes = len(node_coords)
    print("Number of Nodes:",num_nodes)
    initial_routes = greedy_initial_solution()

    optimized_routes_tabu, optimized_route_distance_tabu = tabu_search_cvrp(initial_routes, demands, vehicle_capacity,
                                                                  max_iterations = max_iterations, tabu_size= tabu_size,
                                                                  num_random_swaps = num_random_swaps)
    
    print("Tabu Optimized Routes: ", optimized_routes_tabu)
    print("Tabue Search Distance: ", optimized_route_distance_tabu)
    
    test_capacity_constraint(optimized_routes_tabu, demands, vehicle_capacity)
    
    #plot_CVRP_solution(optimized_routes_tabu, node_coords)
# Out:
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 778) =====================
# Number of Nodes: 34
# Tabu Optimized Routes:  [[26, 4, 33, 22, 9, 12, 3, 18], [29, 11, 23, 27, 24, 30, 5], [32, 28, 31, 17, 19, 25, 15, 7], [13, 10, 21, 2, 16, 20], [1, 8, 6, 14]]
# Tabue Search Distance:  839.0289629142868
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 75 <= 100
# Vehicle 5 is within capacity: 85 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 784) =====================
# Number of Nodes: 32
# Tabu Optimized Routes:  [[20, 14, 12, 1, 6, 23, 28, 8, 18, 5], [27, 22, 9, 15, 25, 10, 29], [26, 13, 31, 19, 17, 21, 16], [7, 2, 3, 4, 11, 24], [30]]
# Tabue Search Distance:  1014.7514788644532
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 96 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 14 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 799) =====================
# Number of Nodes: 36
# Tabu Optimized Routes:  [[20, 34, 14, 24, 27, 11, 16], [18, 32, 22, 17, 29, 33, 21, 25], [1, 13, 30, 31, 3, 6, 4, 19, 12], [15, 8, 35, 2, 23, 28, 9, 5], [10, 7, 26]]
# Tabue Search Distance:  917.441978104133
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 86 <= 100
# Vehicle 4 is within capacity: 98 <= 100
# Vehicle 5 is within capacity: 58 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 661) =====================
# Number of Nodes: 33
# Tabu Optimized Routes:  [[24, 11, 18, 28, 23, 15, 4, 12], [2, 32, 20, 5, 7, 8, 26, 13], [29, 16, 3, 9, 17, 10], [6, 19, 14, 21, 1, 31, 22], [30, 25, 27]]
# Tabue Search Distance:  811.351868178885
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 96 <= 100
# Vehicle 3 is within capacity: 94 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 57 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 669) =====================
# Number of Nodes: 37
# Tabu Optimized Routes:  [[15, 16, 22, 7, 4, 33, 5, 6, 10], [34, 29, 32, 28, 31, 26, 30, 35, 18, 25], [21, 1, 17, 14, 20, 19, 2, 23], [13, 12, 9, 8, 27, 11, 24, 3], [36]]
# Tabue Search Distance:  781.0922749033662
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 92 <= 100
# Vehicle 5 is within capacity: 20 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 730) =====================
# Number of Nodes: 38
# Tabu Optimized Routes:  [[28, 31, 37, 25, 4, 16, 1, 3, 12, 26], [19, 18, 20, 32, 15, 36, 13, 17], [11, 27, 22, 5, 7, 24], [2, 14, 33, 35, 23, 8, 9], [21, 10, 29, 30, 34, 6]]
# Tabue Search Distance:  836.1259621755617
# Vehicle 1 is within capacity: 92 <= 100
# Vehicle 2 is within capacity: 98 <= 100
# Vehicle 3 is within capacity: 94 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# ===================== (Augerat et al, No of trucks: 5, Optimal value: 822) =====================
# Number of Nodes: 39
# Tabu Optimized Routes:  [[19, 25, 12, 18, 9, 4], [31, 1, 15, 29, 23, 20, 16, 7, 22, 3, 17, 8], [21, 30, 13, 28, 6, 36, 26, 11], [14, 27, 34, 37, 35, 24], [33, 5, 32, 10, 2, 38]]
# Tabue Search Distance:  933.7656958547011
# Vehicle 1 is within capacity: 89 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 94 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 93 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 831) =====================
# Number of Nodes: 39
# Tabu Optimized Routes:  [[24, 28, 9, 29], [3, 12, 38, 37, 35, 25, 14, 31, 30], [6, 21, 23, 1, 36, 17, 11], [26, 5, 32, 7, 8, 33, 19, 10, 27, 20], [18, 22, 34, 16, 4, 2], [15, 13]]
# Tabue Search Distance:  935.5472068990738
# Vehicle 1 is within capacity: 55 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 86 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 99 <= 100
# Vehicle 6 is within capacity: 88 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 949) =====================
# Number of Nodes: 37
# Tabu Optimized Routes:  [[24, 16, 7, 14, 18, 4, 17, 19, 1, 12], [29, 36, 6, 20, 8, 5, 33, 28], [26, 21, 2, 23, 11, 22], [10, 30, 15, 32, 27], [35, 25, 13], [34, 31, 9, 3]]
# Tabue Search Distance:  1293.2574126786826
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 93 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 82 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 742) =====================
# Number of Nodes: 33
# Tabu Optimized Routes:  [[14, 1, 6, 18, 23, 24, 31], [25, 21, 16, 30, 27, 28], [5, 7, 2, 9, 15, 20, 19], [13, 3, 8, 4, 26, 22], [17, 29, 11], [32, 10, 12]]
# Tabue Search Distance:  814.1177054223876
# Vehicle 1 is within capacity: 94 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 60 <= 100
# Vehicle 6 is within capacity: 89 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 937) =====================
# Number of Nodes: 44
# Tabu Optimized Routes:  [[34, 26, 10, 33, 5, 27, 7], [39, 12, 17, 6, 29, 22, 41, 9, 38, 36], [3, 25, 40, 43, 13, 14], [21, 37, 32, 42, 16, 20, 11, 24], [2, 23, 1, 35, 18, 30], [4, 19, 15, 28, 8, 31]]
# Tabue Search Distance:  1124.5611129791998
# Vehicle 1 is within capacity: 91 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 95 <= 100
# Vehicle 4 is within capacity: 97 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 92 <= 100
# ===================== (Augerat et al, No of trucks: 6, Optimal value: 944) =====================
# Number of Nodes: 45
# Tabu Optimized Routes:  [[12, 42, 4, 16, 3, 8, 41, 33], [1, 6, 44, 34, 40, 11, 19, 32, 9], [38, 2, 25, 15, 36, 39, 22, 23], [17, 18, 43, 27, 29, 26], [24, 37, 14, 31, 35], [20, 5, 21, 10, 13, 28, 7]]
# Tabue Search Distance:  1136.7326808039434
# Vehicle 1 is within capacity: 95 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 97 <= 100
# Vehicle 5 is within capacity: 95 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1010) =====================
# Number of Nodes: 53
# Tabu Optimized Routes:  [[7, 22, 30, 44, 29, 49, 10, 26, 38, 40, 18], [31, 20, 6, 35, 27, 51, 1, 25], [3, 21, 13, 14, 5, 39], [9, 17, 41, 11, 34, 52, 24], [4, 28, 37, 2, 36, 50, 43, 19, 32, 15, 48], [42, 23, 16, 45, 12, 47], [33, 46, 8]]
# Tabue Search Distance:  1220.3215425057394
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 92 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 93 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 81 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 914) =====================
# Number of Nodes: 46
# Tabu Optimized Routes:  [[17, 9, 28, 21, 31, 20, 41, 34, 40, 33, 11], [45, 6, 43, 30, 4, 13, 14, 38, 36, 5], [32, 7, 10, 44, 25, 18], [26, 2, 37, 22, 3], [19, 8, 42, 35, 12, 39], [15, 24, 16, 1, 27, 29], [23]]
# Tabue Search Distance:  1110.643369395172
# Vehicle 1 is within capacity: 97 <= 100
# Vehicle 2 is within capacity: 98 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 96 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 97 <= 100
# Vehicle 7 is within capacity: 18 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1167) =====================
# Number of Nodes: 54
# Tabu Optimized Routes:  [[43, 4, 28, 5, 7, 39, 50, 20, 23], [52, 30, 16, 6, 32, 13, 11, 38, 26, 35], [18, 49, 29, 15, 10, 1, 36, 17, 45], [34, 41, 46, 51, 42, 2, 8, 19, 37, 12], [25, 47, 24, 48, 40, 31, 27], [44, 9, 33, 21], [14, 22, 3, 53]]
# Tabue Search Distance:  1374.511133395139
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 72 <= 100
# Vehicle 7 is within capacity: 97 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1146) =====================
# Number of Nodes: 45
# Tabu Optimized Routes:  [[12, 39, 34, 26, 4, 6, 21, 2, 8, 38], [35, 32, 13, 18, 7, 16, 20, 40], [23, 25, 42, 37, 1, 30, 5], [31, 29, 36, 19, 22], [28, 3, 11, 43, 41, 27], [17, 15, 10, 9], [14, 33, 44, 24]]
# Tabue Search Distance:  1300.4079452885708
# Vehicle 1 is within capacity: 96 <= 100
# Vehicle 2 is within capacity: 96 <= 100
# Vehicle 3 is within capacity: 97 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 89 <= 100
# Vehicle 6 is within capacity: 78 <= 100
# Vehicle 7 is within capacity: 79 <= 100
# ===================== (Augerat et al, No of trucks: 7, Optimal value: 1073) =====================
# Number of Nodes: 48
# Tabu Optimized Routes:  [[31, 1, 6, 22, 38, 25, 19, 3, 7], [2, 10, 33, 30, 13, 24, 28], [43, 5, 12, 23, 44, 35, 14], [32, 36, 37, 45, 47, 41], [8, 15, 42, 39, 20, 26, 27], [40, 34, 9, 4, 11, 46, 21, 29, 16], [18, 17]]
# Tabue Search Distance:  1255.4887330641006
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 96 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 97 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# Vehicle 7 is within capacity: 38 <= 100
# ===================== (Augerat et al, No of trucks: 8, Optimal value: 1288) =====================
# Number of Nodes: 62
# Tabu Optimized Routes:  [[28, 15, 7, 20, 19, 14, 6, 32, 57, 61], [13, 18, 49, 11, 25, 5, 60, 31, 34, 26, 35, 4, 21, 9, 54, 53], [52, 36, 16, 37, 22, 44, 2, 38], [47, 39, 27, 23, 41, 24, 45], [10, 8, 43, 40, 29, 51], [55, 50, 33, 58, 17, 59], [30, 46, 42, 3, 1], [12, 48, 56]]
# Tabue Search Distance:  1538.189848198048
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 98 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 85 <= 100
# Vehicle 7 is within capacity: 100 <= 100
# Vehicle 8 is within capacity: 53 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1174) =====================
# Number of Nodes: 65
# Tabu Optimized Routes:  [[51, 17, 47, 64, 6, 26, 46, 57, 18, 19], [39, 62, 28, 63, 48, 54, 7, 11], [3, 36, 35, 50, 16, 41, 38, 42, 61, 5], [34, 31, 9, 22, 14, 15], [21, 59, 40, 58, 32, 8, 52, 25], [23, 33, 1, 12, 13, 55, 29], [43, 37, 30, 4, 27, 49], [45, 53, 20, 2, 60], [24, 10, 56, 44]]
# Tabue Search Distance:  1506.285749056384
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 96 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 97 <= 100
# Vehicle 8 is within capacity: 99 <= 100
# Vehicle 9 is within capacity: 87 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1159) =====================
# Number of Nodes: 69
# Tabu Optimized Routes:  [[19, 24, 43, 52, 26, 54, 5, 46], [28, 34, 14, 42, 25, 11, 63, 37, 16, 1, 10], [7, 27, 65, 55, 60, 4, 47, 57, 29, 2], [31, 18, 53, 9, 30, 3, 15, 13, 35, 45], [38, 8, 59, 20, 41, 68], [67, 64, 61, 21, 33, 49, 6, 66, 58], [12, 40, 39, 56, 62], [50, 48, 36, 17, 32], [23, 51, 44, 22]]
# Tabue Search Distance:  1465.3327434728499
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 66 <= 100
# Vehicle 6 is within capacity: 96 <= 100
# Vehicle 7 is within capacity: 96 <= 100
# Vehicle 8 is within capacity: 89 <= 100
# Vehicle 9 is within capacity: 98 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1034) =====================
# Number of Nodes: 61
# Tabu Optimized Routes:  [[14, 7, 43, 26, 55], [9, 35, 34, 57, 17, 12, 22, 4, 32, 33], [23, 10, 37, 45, 59, 30, 42], [50, 13, 52, 31, 60, 11, 44, 39], [28, 1, 16, 48, 18, 56, 27, 51], [15, 3, 38], [58, 25, 6, 20, 41, 8, 40], [47, 21, 29, 36, 54, 46, 5], [24, 49, 53, 2, 19]]
# Tabue Search Distance:  1226.8533476453274
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 96 <= 100
# Vehicle 8 is within capacity: 98 <= 100
# Vehicle 9 is within capacity: 97 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1401) =====================
# Number of Nodes: 64
# Tabu Optimized Routes:  [[6, 10, 41, 56, 52, 13, 61, 60, 16, 32], [29, 57, 14, 27, 44, 39, 36, 31], [25, 15, 53, 37, 23, 19, 20], [38, 18, 22, 12, 43, 11, 45], [3, 30, 55, 49, 59, 51], [9, 34, 5, 58, 2, 63, 47], [17, 1, 28, 35, 26, 21, 7, 40, 50], [24, 8, 46, 54, 4, 42], [33, 48, 62]]
# Tabue Search Distance:  1607.3055149591744
# Vehicle 1 is within capacity: 91 <= 100
# Vehicle 2 is within capacity: 96 <= 100
# Vehicle 3 is within capacity: 95 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 88 <= 100
# Vehicle 6 is within capacity: 88 <= 100
# Vehicle 7 is within capacity: 95 <= 100
# Vehicle 8 is within capacity: 96 <= 100
# Vehicle 9 is within capacity: 99 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1073) =====================
# Number of Nodes: 55
# Tabu Optimized Routes:  [[36, 8, 21, 12, 32, 10, 53, 40], [41, 18, 1, 35, 43, 44, 19], [4, 7, 42, 31, 20, 14, 48, 50], [37, 3, 17, 34, 46, 26], [30, 22, 13, 54, 23, 24, 52], [5, 38, 16, 39, 49, 9, 47], [33, 51, 11, 15, 2, 29], [6, 45], [25, 27, 28]]
# Tabue Search Distance:  1368.0735086869863
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 99 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 97 <= 100
# Vehicle 6 is within capacity: 99 <= 100
# Vehicle 7 is within capacity: 99 <= 100
# Vehicle 8 is within capacity: 86 <= 100
# Vehicle 9 is within capacity: 60 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1354) =====================
# Number of Nodes: 60
# Tabu Optimized Routes:  [[55, 35, 15, 17, 37, 57, 8, 19, 33], [16, 20, 25, 46, 40, 11, 4, 21, 6, 2, 49, 18], [3, 28, 53, 30, 44, 31, 47], [58, 10, 42, 22, 54, 32, 23, 34], [50, 39, 43, 56, 26, 27, 29], [52, 38, 59, 7, 13], [24, 1, 36, 5, 48], [45, 51, 9, 12], [41, 14]]
# Tabue Search Distance:  1607.2436916570534
# Vehicle 1 is within capacity: 99 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 96 <= 100
# Vehicle 7 is within capacity: 100 <= 100
# Vehicle 8 is within capacity: 100 <= 100
# Vehicle 9 is within capacity: 34 <= 100
# ===================== (Augerat et al, No of trucks: 9, Optimal value: 1616) =====================
# Number of Nodes: 63
# Tabu Optimized Routes:  [[60, 48, 49, 36, 42, 38, 46, 1, 31], [25, 12, 22, 17, 37, 6], [10, 23, 43, 18, 4, 47, 62, 52], [54, 29, 34, 2, 30, 5, 27, 13], [19, 7, 16, 50, 35, 51, 57, 32, 58, 53], [15, 28, 21, 14, 40, 55, 33], [20, 8, 59, 24, 45], [61, 3, 41, 9, 39], [11, 44, 56, 26]]
# Tabue Search Distance:  1855.0153718676168
# Vehicle 1 is within capacity: 100 <= 100
# Vehicle 2 is within capacity: 99 <= 100
# Vehicle 3 is within capacity: 96 <= 100
# Vehicle 4 is within capacity: 97 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 100 <= 100
# Vehicle 7 is within capacity: 97 <= 100
# Vehicle 8 is within capacity: 98 <= 100
# Vehicle 9 is within capacity: 90 <= 100
# ===================== (Augerat et al, No of trucks: 10, Optimal value: 1314) =====================
# Number of Nodes: 63
# Tabu Optimized Routes:  [[48, 36, 52, 38, 4, 50, 7], [20, 26, 13, 28, 57, 47, 11], [17, 62, 31, 24, 21, 61, 54, 40, 29], [30, 43, 10, 59, 5, 18, 49, 15, 45], [25, 56, 53, 14, 1, 41, 42, 19, 39], [32, 44, 34, 51, 58, 22, 23], [16, 35, 6, 8, 27], [46, 60], [3, 2, 9, 12], [33, 55, 37]]
# Tabue Search Distance:  1736.6012383963775
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 99 <= 100
# Vehicle 5 is within capacity: 100 <= 100
# Vehicle 6 is within capacity: 98 <= 100
# Vehicle 7 is within capacity: 96 <= 100
# Vehicle 8 is within capacity: 85 <= 100
# Vehicle 9 is within capacity: 84 <= 100
# Vehicle 10 is within capacity: 72 <= 100
# ===================== (Augerat et al, No of trucks: 10, Optimal value: 1763) =====================
# Number of Nodes: 80
# Tabu Optimized Routes:  [[49, 51, 60, 17, 31, 27, 59, 29, 5], [11, 34, 2, 37, 8, 68, 6, 24], [36, 53, 66, 67, 70, 38, 58, 50, 76], [42, 74, 39, 3, 77, 73], [21, 10, 63, 62, 44, 12, 13], [57, 16, 43, 61, 20, 78, 30, 23], [72, 45, 22, 32, 4, 54, 9, 33, 15, 64], [71, 28, 79, 48, 18, 52, 14], [46, 25, 41, 55, 56, 69, 65, 35, 26, 19, 47, 75], [1, 7, 40]]
# Tabue Search Distance:  1933.217234892455
# Vehicle 1 is within capacity: 98 <= 100
# Vehicle 2 is within capacity: 100 <= 100
# Vehicle 3 is within capacity: 100 <= 100
# Vehicle 4 is within capacity: 100 <= 100
# Vehicle 5 is within capacity: 96 <= 100
# Vehicle 6 is within capacity: 95 <= 100
# Vehicle 7 is within capacity: 99 <= 100
# Vehicle 8 is within capacity: 97 <= 100
# Vehicle 9 is within capacity: 94 <= 100
# Vehicle 10 is within capacity: 63 <= 100
